# %%
import openturns as ot
import otagrum as otagr
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

def petiteDemo(Y,Z,X):
    """
    Print some results just for fun
    """
    _,p,b=t.isIndep(Y,Z,[])
    if b:
        print(f"{Y} et {Z} sont indépendants ({100*p:5.3}%)")
    else:
        print(f"{Y} et {Z} ne sont pas indépendants ({100*p:5.3}%)")
    print(" alors que")
    
    _,p,b=t.isIndep(Y,Z,X)
    if t.isIndep(Y,Z,X)[2]:
        print(f"{Y} et {Z} sont indépendants sachant {X} ({100*p:5.3}%)")
    else:
        print(f"{Y} et {Z} ne sont pas indépendants sachant {X} ({100*p:5.3}%)")

# %%
X = ot.Sample.ImportFromCSVFile("advised.csv")

alpha = 0.1

t=otagr.ContinuousTTest(X)
t.setAlpha(alpha)

conditionning = 3
learner = otagr.ContinuousPC(X, conditionning, alpha)

# %%
dag = learner.learnDAG()
gnb.sideBySide(learner.inferSkeleton(),learner.inferPDAG(learner.inferSkeleton()),gnb.getDot(dag.toDot()))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="208pt" viewBox="0.00 0.00 288.00 207.86" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(.6261 .6261) rotate(0) translate(4 328)">
# <title>no_name</title>
# <!-- 0 -->
# <g class="node" id="node1">
# <title>0</title>
# <ellipse cx="55" cy="-306" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="55" y="-302.3">0</text>
# </g>
# <!-- 2 -->
# <g class="node" id="node3">
# <title>2</title>
# <ellipse cx="27" cy="-234" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-230.3">2</text>
# </g>
# <!-- 0&#45;&gt;2 -->
# <g class="edge" id="edge2">
# <title>0-&gt;2</title>
# <path d="M48.222,-288.5708C43.8521,-277.3339 38.1894,-262.7727 33.8126,-251.5182" fill="none" stroke="#000000"/>
# </g>
# <!-- 3 -->
# <g class="node" id="node4">
# <title>3</title>
# <ellipse cx="99" cy="-234" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-230.3">3</text>
# </g>
# <!-- 0&#45;&gt;3 -->
# <g class="edge" id="edge1">
# <title>0-&gt;3</title>
# <path d="M65.2051,-289.3008C72.2118,-277.8352 81.4848,-262.6612 88.5447,-251.1086" fill="none" stroke="#000000"/>
# </g>
# <!-- 1 -->
# <g class="node" id="node2">
# <title>1</title>
# <ellipse cx="154" cy="-306" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="154" y="-302.3">1</text>
# </g>
# <!-- 1&#45;&gt;3 -->
# <g class="edge" id="edge3">
# <title>1-&gt;3</title>
# <path d="M141.5196,-289.6621C132.5186,-277.8788 120.4207,-262.0416 111.431,-250.2733" fill="none" stroke="#000000"/>
# </g>
# <!-- 4 -->
# <g class="node" id="node5">
# <title>4</title>
# <ellipse cx="90" cy="-162" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="90" y="-158.3">4</text>
# </g>
# <!-- 1&#45;&gt;4 -->
# <g class="edge" id="edge4">
# <title>1-&gt;4</title>
# <path d="M152.7608,-287.924C150.8962,-269.1363 146.2853,-239.2792 135,-216 127.8666,-201.2852 115.8715,-187.1797 106.0589,-177.0772" fill="none" stroke="#000000"/>
# </g>
# <!-- 13 -->
# <g class="node" id="node14">
# <title>13</title>
# <ellipse cx="209" cy="-234" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="209" y="-230.3">13</text>
# </g>
# <!-- 1&#45;&gt;13 -->
# <g class="edge" id="edge5">
# <title>1-&gt;13</title>
# <path d="M166.4804,-289.6621C175.4814,-277.8788 187.5793,-262.0416 196.569,-250.2733" fill="none" stroke="#000000"/>
# </g>
# <!-- 2&#45;&gt;4 -->
# <g class="edge" id="edge6">
# <title>2-&gt;4</title>
# <path d="M40.6701,-218.3771C51.2373,-206.3003 65.7961,-189.6616 76.3566,-177.5924" fill="none" stroke="#000000"/>
# </g>
# <!-- 7 -->
# <g class="node" id="node8">
# <title>7</title>
# <ellipse cx="90" cy="-90" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="90" y="-86.3">7</text>
# </g>
# <!-- 4&#45;&gt;7 -->
# <g class="edge" id="edge7">
# <title>4-&gt;7</title>
# <path d="M90,-143.8314C90,-133 90,-119.2876 90,-108.4133" fill="none" stroke="#000000"/>
# </g>
# <!-- 5 -->
# <g class="node" id="node6">
# <title>5</title>
# <ellipse cx="281" cy="-306" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="281" y="-302.3">5</text>
# </g>
# <!-- 6 -->
# <g class="node" id="node7">
# <title>6</title>
# <ellipse cx="281" cy="-234" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="281" y="-230.3">6</text>
# </g>
# <!-- 5&#45;&gt;6 -->
# <g class="edge" id="edge8">
# <title>5-&gt;6</title>
# <path d="M281,-287.8314C281,-277 281,-263.2876 281,-252.4133" fill="none" stroke="#000000"/>
# </g>
# <!-- 8 -->
# <g class="node" id="node9">
# <title>8</title>
# <ellipse cx="90" cy="-18" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="90" y="-14.3">8</text>
# </g>
# <!-- 7&#45;&gt;8 -->
# <g class="edge" id="edge9">
# <title>7-&gt;8</title>
# <path d="M90,-71.8314C90,-61 90,-47.2876 90,-36.4133" fill="none" stroke="#000000"/>
# </g>
# <!-- 9 -->
# <g class="node" id="node10">
# <title>9</title>
# <ellipse cx="353" cy="-306" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="353" y="-302.3">9</text>
# </g>
# <!-- 11 -->
# <g class="node" id="node12">
# <title>11</title>
# <ellipse cx="353" cy="-234" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="353" y="-230.3">11</text>
# </g>
# <!-- 9&#45;&gt;11 -->
# <g class="edge" id="edge10">
# <title>9-&gt;11</title>
# <path d="M353,-287.8314C353,-277 353,-263.2876 353,-252.4133" fill="none" stroke="#000000"/>
# </g>
# <!-- 10 -->
# <g class="node" id="node11">
# <title>10</title>
# <ellipse cx="425" cy="-306" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="425" y="-302.3">10</text>
# </g>
# <!-- 12 -->
# <g class="node" id="node13">
# <title>12</title>
# <ellipse cx="353" cy="-162" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="353" y="-158.3">12</text>
# </g>
# <!-- 11&#45;&gt;12 -->
# <g class="edge" id="edge11">
# <title>11-&gt;12</title>
# <path d="M353,-215.8314C353,-205 353,-191.2876 353,-180.4133" fill="none" stroke="#000000"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="208pt" viewBox="0.00 0.00 288.00 207.86" width="288pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(.6261 .6261) rotate(0) translate(4 328)">
# <title>no_name</title>
# <!-- 0 -->
# <g class="node" id="node1">
# <title>0</title>
# <ellipse cx="55" cy="-306" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="55" y="-302.3">0</text>
# </g>
# <!-- 2 -->
# <g class="node" id="node3">
# <title>2</title>
# <ellipse cx="27" cy="-234" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-230.3">2</text>
# </g>
# <!-- 0&#45;&gt;2 -->
# <g class="edge" id="edge2">
# <title>0-&gt;2</title>
# <path d="M48.222,-288.5708C43.8521,-277.3339 38.1894,-262.7727 33.8126,-251.5182" fill="none" stroke="#000000"/>
# </g>
# <!-- 3 -->
# <g class="node" id="node4">
# <title>3</title>
# <ellipse cx="99" cy="-234" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-230.3">3</text>
# </g>
# <!-- 0&#45;&gt;3 -->
# <g class="edge" id="edge1">
# <title>0-&gt;3</title>
# <path d="M65.2051,-289.3008C72.2118,-277.8352 81.4848,-262.6612 88.5447,-251.1086" fill="none" stroke="#000000"/>
# </g>
# <!-- 1 -->
# <g class="node" id="node2">
# <title>1</title>
# <ellipse cx="154" cy="-306" fill="none" rx="27" ry="18" stroke="#000000"/>
# <text fill="#000000" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="154" y="-302.3">1</text>
# </g>
# <!-- 1&#45;&gt;3 -->
# <g class="edge" id="edge3">
# <title>1-&gt;3</title>
# <path d="M141.5196,-289.6621C132.5186,-277.8788 120.4207,-262.0416 111.431,-250.2733" fill="none" stroke="#000000"/>
# </g>
# <!-- 4 -->
# <g class="node" id="node5">
# <title>4</title>
# <ellipse cx="90" cy="-162" fill="none" rx="2

# %%
petiteDemo(3,13,[1])
# Out:
# 3 et 13 ne sont pas indépendants ( 8.78%)
#  alors que
# 3 et 13 sont indépendants sachant [1] ( 71.8%)

# %%
petiteDemo(2,8,[7])
# Out:
# 2 et 8 sont indépendants ( 89.8%)
#  alors que
# 2 et 8 sont indépendants sachant [7] ( 56.6%)

# %%
print(t)
# Out:
# Data dimension : 14
# Data size : 200
# Cache :
#       |2 : [1,13]:6, [4,1]:5, [4,13]:5, [2,3]:6, [0,2]:5, [0,3]:5, [3,13]:6, [1,3]:5, [1,13]:5, [4,8]:6, [7,4]:5, [7,8]:5, [3,0]:6, [2,3]:5, [2,0]:5, [3,2]:6, [9,12]:6, [11,9]:5, [11,12]:5, [1,7]:6, [4,7]:5, [2,8]:6, [7,2]:5
#       |3 : [4,1,13]:5, [0,2,3]:5, [1,3,13]:5, [7,4,8]:5, [2,3,0]:5, [0,3,2]:5, [11,9,12]:5, [4,1,7]:5, [7,2,8]:5
#
# alpha :0.1
